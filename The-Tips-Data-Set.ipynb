# %% [markdown]
# # David Markham
# # Fundamentals of Data Analysis
# # An Investigation Into the Tips Data-Set
# ![image](ImagesFun/Tips.jpg)
# Source (Inquiries Journal, 2019)
#
# ### Below I will be investigating the Waiters Tips Data-Set, demonstrating relationships between the variables in the data-set, and finally looking at ways management may improve their business based on the data extracted and displayed from the data-set.
#
#
#
# #### The main purpose of this project is to try and predict what the tips will likely be, on a given day, for the waiter.
#
# - This will be done through various libraries, which will display our findings and statistics.
#
#
# - We will be using the data-set to see what the tips were like, smokers/non-smokers, lunch/dinner numbers, male/female bill payers, busy or quiet days, min tip, max tip, mean, etc.
#
#
# - Will be discussing relationships between the values, total bill and tip amount, day of week and tip size, smoker versus non/smoker, lunch and dinner tips, and so on. If someone spends an x amount on their dinner, what would the tip be? Can we see a relationship in the evening time tip size and day of week, esp at weekends when alcohol maybe involved, and the tip size is increased due to this maybe?
#
# - Summary of all our stats and plots I have pulled from the data-set.
#
# - Findings, what did I find interesting from all the variabes we analyzed, can the data be used to improve the company's present strategy, resources, and enhance competitive advantage? Tip rates can be a very effective tool, in terms of identifying strengths/weaknesses within a company.
#
#
# #### And finally analyzing all pairs of variables, selecting certain subsets of the data and discussing some interesting findings.
#
# 1. Does one sex leave larger tips than the other, if so, why this is the case?
# 2. Does the party size, times, esp at weekends, evening time when alcohol maybe involved, determine tip size?
# 3. Can management improve the business from some of the stats in this data-set?
# 4. Should tips be raised or reduced?
# 5. Tips size can determine your overall service at a restaurant, does it need to be improved?
# 6. Usually in the U.S.A, there is an unwritten rule of thumb, which a 15% tip is standard to be given, and 20-25% when service is exceeded. Does the mangement need to improve employee training to enhance overall service, based on the tips received by it's employees?

# %% [markdown]
# ### Import Pandas
#
# ![image](ImagesFun/Pandas1.jpg) Source(Data Flair, 2018)
#
# - Pandas is a Python programming package, it manipulates and analyzes data, offers data structures and operations for manipulating numerical tables and time series.
# - Lets you read your files, csv in this case, into a data structure.
# - Data-frame (table with columns which have names, and rows that are indexed)
# - Lets you get all kinds of statistics, min, max, mean, std etc.

# %% [markdown]
# **Import Libraries**
#
# <a href="https://pandas.pydata.org/">Pandas</a>, data manipulation and analysis, <a href="https://seaborn.pydata.org/">Seaborn</a>, draws attractive and informative statistical graphics, <a href="https://numpy.org/">Numpy</a>, fundamental package for scientific computing with Python, and <a href="https://matplotlib.org/">Matplotlib.pyplot</a>, plotting library. We will be using these Python libraries to pulls stats from the data set, and also to visualize the findings on plots, making it easier to identify relationships between the variables.

# %%
# Import pandas library.
import pandas as pd

# %%
import numpy as np # Allows us to work with multi-dimensional arrays, with high level mathematical functions.

# %%
import matplotlib.pyplot as plt # Displays all kinds of plots. 
import seaborn as sns # Data visualization library based on matplotlib.

# %% [markdown]
# ### Import the csv file from the url address.

# %%
# Import the csv file from url address.
df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv') # Reads the df using Pandas library.

# %% [markdown]
# - Displays all the data from the csv file you just imported.
# - We have seven columns, made up of integers and strings.
# - We have the index column, this is the numbers of days the data was recorded over.
# - Which in turn, outputs 244 rows of data.

# %%
# Displays dataframe we just imported.
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %% [markdown]
# Displays all the information, for the row and columns, data types etc.

# %%
# Displays the Df information.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null object
# smoker        244 non-null object
# day           244 non-null object
# time          244 non-null object
# size          244 non-null int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.4+ KB

# %% [markdown]
# ### Below we can look at some commands to call data from the csv file we imported.

# %% [markdown]
# - Selecting rows and columns.
# - Extracting data, from certain columns and rows.
# - Mean, min, max etc.

# %% [markdown]
# Select a **single** column.

# %%
# Displays the total bill column from the dataset.
df['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
# 5      25.29
# 6       8.77
# 7      26.88
# 8      15.04
# 9      14.78
# 10     10.27
# 11     35.26
# 12     15.42
# 13     18.43
# 14     14.83
# 15     21.58
# 16     10.33
# 17     16.29
# 18     16.97
# 19     20.65
# 20     17.92
# 21     20.29
# 22     15.77
# 23     39.42
# 24     19.82
# 25     17.81
# 26     13.37
# 27     12.69
# 28     21.70
# 29     19.65
#        ...
# 214    28.17
# 215    12.90
# 216    28.15
# 217    11.59
# 218     7.74
# 219    30.14
# 220    12.16
# 221    13.42
# 222     8.58
# 223    15.98
# 224    13.42
# 225    16.27
# 226    10.09
# 227    20.45
# 228    13.28
# 229    22.12
# 230    24.01
# 231    15.69
# 232    11.61
# 233    10.77
# 234    15.53
# 235    10.07
# 236    12.60
# 237    32.83
# 238    35.83
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %% [markdown]
# Select **multiple** columns.

# %%
# Can select multiple rows, columns.
# Here we selected sex and size of the party.
df[['sex', 'size']]
# Out:
#         sex  size
# 0    Female     2
# 1      Male     3
# 2      Male     3
# 3      Male     2
# 4    Female     4
# 5      Male     4
# 6      Male     2
# 7      Male     4
# 8      Male     2
# 9      Male     2
# 10     Male     2
# 11   Female     4
# 12     Male     2
# 13     Male     4
# 14   Female     2
# 15     Male     2
# 16   Female     3
# 17     Male     3
# 18   Female     3
# 19     Male     3
# 20     Male     2
# 21   Female     2
# 22   Female     2
# 23     Male     4
# 24     Male     2
# 25     Male     4
# 26     Male     2
# 27     Male     2
# 28     Male     2
# 29   Female     2
# ..      ...   ...
# 214  Female     3
# 215  Female     2
# 216    Male     5
# 217    Male     2
# 218    Male     2
# 219  Female     4
# 220    Male     2
# 221  Female     2
# 222    Male     1
# 223  Female     3
# 224    Male     2
# 225  Female     2
# 226  Female     2
# 227    Male     4
# 228    Male     2
# 229  Female     2
# 230    Male     4
# 231    Male     3
# ...

# %% [markdown]
# **Locate** and display certain sections of the dataframe.

# %%
# Locates data row two through eight.
# Loc short for locate, default option.
df.loc[2:8]
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2

# %% [markdown]
# Uses **index** to locate data.

# %%
# Gives acess into your row column, and outputs data on your index from row two.
# Index displayed on left side, numbers the rows.
# Index can be displayed by time format also.
# iloc is position of a specfic row/rows you wish to extract your data from.
# loc loactes the row.
df.iloc[2]
# Out:
# total_bill     21.01
# tip              3.5
# sex             Male
# smoker            No
# day              Sun
# time          Dinner
# size               3
# Name: 2, dtype: object

# %% [markdown]
# Locate a single cell.

# %%
# Finds individual cell, this case row five in the sex column.
df.at[5, 'sex']
# Out:
# 'Male'

# %% [markdown]
# Call the **head** of the data-frame.

# %%
# Calls head of df.
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# And the **tail** of the data-frame.

# %%
# Calls Tail of df.
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %% [markdown]
# ### Below we can look at some of the varibales within the data-set, and try and indentify relationships between them. This will be also done using Pandas.
#
#
# ### Statistics
#
#
# ### Total bill/Tip

# %% [markdown]
# Below we can call the function: df..describe(), which will output the totals, <a href="https://www.investopedia.com/terms/s/standarddeviation.asp">standard deviation</a>, the average total bill, average tip and average size of party.
#
# - Total, average, standard deviation(mathematical tool to help us assess how far the values are spread above and below the mean), min and max, 25%, 50% and 75%(It describes the distribution of your data. 50 should be a value that describes the middle of the data, also known as median. The numbers 25, 75 is the border of the upper/lower quarter of the data.)

# %%
# Describes the stats from the dataset.
df.describe() # Displays the stats from the dataset.
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# **Tip percentage for each bill, min, max etc.**

# %%
# Code adapted from: (https://www.xukun-liu.com/notes/notes/python_ClassNote_13-data-aggregation-group-operations-two.html)
df['tip_pct'] = 100 * df['tip'] / df['total_bill'] # tip % = tips * 100 / total bill.
df['tip_pct'].describe() # returns the average tip %.
# Out:
# count    244.000000
# mean      16.080258
# std        6.107220
# min        3.563814
# 25%       12.912736
# 50%       15.476977
# 75%       19.147549
# max       71.034483
# Name: tip_pct, dtype: float64

# %% [markdown]
# **Stats for each day**

# %%
# Perform the groupby operation directly on the tip_pct column (Series)
day_order = ['Thur','Fri','Sat','Sun'] # returns the days in order. 
df['tip_pct'].groupby(by=df['day']).describe().loc[day_order] # from the function we created above, group days, returns the stats for each day.
# Out:
#       count       mean       std        min        25%        50%        75%  \
# day
# Thur   62.0  16.127563  3.865182   7.296137  13.820958  15.384615  19.268675
# Fri    19.0  16.991303  4.766531  10.355540  13.373871  15.562472  19.663729
# Sat    87.0  15.315172  5.129259   3.563814  12.386329  15.183246  18.827082
# Sun    76.0  16.689729  8.473889   5.944673  11.998208  16.110332  18.788908
#
#             max
# day
# Thur  26.631158
# Fri   26.348039
# Sat   32.573290
# Sun   71.034483

# %% [markdown]
# Below we can see:
# - The average total bill was just under 20 dollars.
# - Average tip was nealy three dollars.
# - The average amount of guests was 2.5.

# %%
# Average size of total bill, tip and party size.
df.mean()
# Out:
# total_bill    19.785943
# tip            2.998279
# size           2.569672
# dtype: float64

# %% [markdown]
# Define a function which displays the top ten bills with the **highest tips**.

# %%
def top(frame, n=10, column='tip_pct'): # top 10 tips vs total bills, from the tip_pct we created already.
    return frame.sort_values(by=column, ascending=False).head(n) # return the values from top tip rates.

# %%
top(df) # Returns the top ten tips % wise.
# Out:
#      total_bill   tip     sex smoker   day    time  size    tip_pct
# 172        7.25  5.15    Male    Yes   Sun  Dinner     2  71.034483
# 178        9.60  4.00  Female    Yes   Sun  Dinner     2  41.666667
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1  32.573290
# 232       11.61  3.39    Male     No   Sat  Dinner     2  29.198966
# 183       23.17  6.50    Male    Yes   Sun  Dinner     4  28.053517
# 109       14.31  4.00  Female    Yes   Sat  Dinner     2  27.952481
# 149        7.51  2.00    Male     No  Thur   Lunch     2  26.631158
# 93        16.32  4.30  Female    Yes   Fri  Dinner     2  26.348039
# 221       13.42  3.48  Female    Yes   Fri   Lunch     2  25.931446
# 51        10.29  2.60  Female     No   Sun  Dinner     2  25.267250

# %% [markdown]
# Here we can see the **worst tips**. Clearly there were many left well below the average, service bad, training needs to be updated?

# %%
def top(frame, n=25, column='tip_pct'): # top 25 tips vs total bills, from the tip_pct we created already.
    return frame.sort_values(by=column, ascending=True).head(n) # return the values from bottom tip rates.

# %%
top(df)
# Out:
#      total_bill   tip     sex smoker   day    time  size   tip_pct
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2  3.563814
# 102       44.30  2.50  Female    Yes   Sat  Dinner     3  5.643341
# 57        26.41  1.50  Female     No   Sat  Dinner     2  5.679667
# 0         16.99  1.01  Female     No   Sun  Dinner     2  5.944673
# 187       30.46  2.00    Male    Yes   Sun  Dinner     5  6.565988
# 210       30.06  2.00    Male    Yes   Sat  Dinner     3  6.653360
# 48        28.55  2.05    Male     No   Sun  Dinner     3  7.180385
# 146       18.64  1.36  Female     No  Thur   Lunch     3  7.296137
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  7.358352
# 184       40.55  3.00    Male    Yes   Sun  Dinner     2  7.398274
# 182       45.35  3.50    Male    Yes   Sun  Dinner     3  7.717751
# 207       38.73  3.00    Male    Yes   Sat  Dinner     4  7.745933
# 130       19.08  1.50    Male     No  Thur   Lunch     2  7.861635
# ...

# %% [markdown]
# ### Male/Female.
#
# **How many bill payers based on sex**, nearly double the amount of male bill payers.

# %%
df.groupby('sex').count()
# Out:
#         total_bill  tip  smoker  day  time  size
# sex
# Female          87   87      87   87    87    87
# Male           157  157     157  157   157   157

# %% [markdown]
# - **Sums for each sex**. Male paid double the bill size, tips size also double.

# %%
df.groupby('sex').sum() # Function calls totals from variable sex.
# Out:
#         total_bill     tip  size
# sex
# Female     1570.95  246.51   214
# Male       3256.82  485.07   413

# %% [markdown]
# "Research suggests that men actually only tip better for small bills while women tip better for large ones. ... Or, more generally, men are more likely to be perfectly selfish or selfless, tipping very generously or barely at all; women are more likely to be egalitarian, tipping consistently, even for larger bills." (From the Grape Vine, 2016)
#
# Here we can see **tip per cent** average values over the four days for both sexes.

# %%
df1 = df.groupby('sex').sum() # Values for dinner times
df1['percent'] = df1['tip']/df1['total_bill']*100 # Per cent cal for tips
df1.dropna() # displays the data
# Out:
#         total_bill     tip  size    percent
# sex
# Female     1570.95  246.51   214  15.691779
# Male       3256.82  485.07   413  14.893976

# %% [markdown]
# And again we can see the tips **per cent rate over the four days**.
#
# Females average tipping was higher overall.

# %%
df1 = df.groupby(['sex','time']).sum() # Values for dinner times
df1['percent'] = df1['tip']/df1['total_bill']*100 # Per cent cal for tips
df1.dropna() # displays the data
# Out:
#                total_bill     tip  size    percent
# sex    time
# Female Dinner      999.08  156.11   128  15.625375
#        Lunch       571.87   90.40    86  15.807788
# Male   Dinner     2661.22  389.96   335  14.653430
#        Lunch       595.60   95.11    78  15.968771

# %% [markdown]
# Here we can detemine that **females, pay more than males,** esp at weekends, when the **size of party is two people**.

# %%
df1 = df.groupby(['sex','day', 'size']).sum() # Values for sex vs males, times and percent.
df1['percent'] = df1['tip']/df1['total_bill']*100 # Per cent cal for tips
df1.dropna() # displays the data
# Out:
#                   total_bill    tip    percent
# sex    day  size
# Female Fri  2         111.33  22.03  19.788018
#             3          15.98   3.00  18.773467
#        Sat  1          10.32   2.00  19.379845
#             2         347.60  51.17  14.720944
#             3         142.30  19.74  13.872101
#             4          50.83   5.54  10.899075
#        Sun  2          99.92  19.74  19.755805
#             3         108.27  18.17  16.782119
#             4         119.66  17.56  14.674912
#             5          29.85   5.14  17.219430
#        Thur 1          10.07   1.83  18.172790
#             2         330.84  53.71  16.234434
#             3          35.11   4.59  13.073199
#             4         102.02  13.09  12.830817
#             6          56.85   9.20  16.182938
# Male   Fri  1           8.58   1.92  22.377622
#             2         149.82  20.28  13.536243
#             4          40.17   4.73  11.774956
#        Sat  2         544.77  82.26  15.099950
# ...

# %% [markdown]
# Below we can see that **far more males** left tips greater than five dollars. Four females left tips bigger than five dollars, while there was a considerable amount of males tips over five dollars.

# %%
# Here we can use the 'AND' condition in Pandas. A command similar to SQL.
df[(df['sex'] == 'Female') & (df['tip'] > 5.00)] # Select, using boolean, time was dinner, and tip was greater than 5 dollars.
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 52        34.81  5.20  Female     No   Sun  Dinner     4
# 85        34.83  5.17  Female     No  Thur   Lunch     4
# 155       29.85  5.14  Female     No   Sun  Dinner     5
# 214       28.17  6.50  Female    Yes   Sat  Dinner     3

# %%
# Here we can use the 'AND' condition in Pandas.
df[(df['sex'] == 'Male') & (df['tip'] > 5.00)] # Select, using boolean, time was dinner, and tip was greater than 5 dollars.
# Out:
#      total_bill    tip   sex smoker   day    time  size
# 23        39.42   7.58  Male     No   Sat  Dinner     4
# 44        30.40   5.60  Male     No   Sun  Dinner     4
# 47        32.40   6.00  Male     No   Sun  Dinner     4
# 59        48.27   6.73  Male     No   Sat  Dinner     4
# 88        24.71   5.85  Male     No  Thur   Lunch     2
# 116       29.93   5.07  Male     No   Sun  Dinner     4
# 141       34.30   6.70  Male     No  Thur   Lunch     6
# 170       50.81  10.00  Male    Yes   Sat  Dinner     3
# 172        7.25   5.15  Male    Yes   Sun  Dinner     2
# 181       23.33   5.65  Male    Yes   Sun  Dinner     2
# 183       23.17   6.50  Male    Yes   Sun  Dinner     4
# 211       25.89   5.16  Male    Yes   Sat  Dinner     4
# 212       48.33   9.00  Male     No   Sat  Dinner     4
# 239       29.03   5.92  Male     No   Sat  Dinner     3

# %% [markdown]
# ### Days
#
# The **total amount of bills** for each day, with Saturday the busiest, and Friday extremely quiet.

# %%
# Function which counts and displays the amount bills for each day.
df.groupby('day').count()
# Out:
#       total_bill  tip  sex  smoker  time  size
# day
# Fri           19   19   19      19    19    19
# Sat           87   87   87      87    87    87
# Sun           76   76   76      76    76    76
# Thur          62   62   62      62    62    62

# %% [markdown]
# Again we can see that Saturday and Sunday were clearly the busiest days, with total bill amounts, total tip and size of party for each day displayed.

# %%
# Displays the sum of bills, tips and amount of guests for each day.
df.groupby('day').sum()
# Out:
#       total_bill     tip  size
# day
# Fri       325.88   51.96    40
# Sat      1778.40  260.40   219
# Sun      1627.16  247.39   216
# Thur     1096.33  171.83   152

# %% [markdown]
# Average tip for dinner and lunch.

# %%
df['tip_pct'].groupby(by=df['time']).mean()
# Out:
# time
# Dinner    15.951779
# Lunch     16.412793
# Name: tip_pct, dtype: float64

# %% [markdown]
# Below we can see what day was the busiest, and would produce the greatest average tips. Friday did return the highest tip rates vs total bill, but it was extremly quiet compared to the other days. Saturday and Sunday were the busy days, with average tip being 14.6% and 15.2%.

# %%
df1= df.groupby('day').sum() # Values for dinner times
df1['percent'] = df1['tip']/df1['total_bill']*100 # Per cent cal for tips
df1.dropna() # displays the data
# Out:
#       total_bill     tip  size    percent
# day
# Fri       325.88   51.96    40  15.944519
# Sat      1778.40  260.40   219  14.642375
# Sun      1627.16  247.39   216  15.203791
# Thur     1096.33  171.83   152  15.673201

# %% [markdown]
# Now, let's apply our top function to some groupby objects, the **highest tip % for each day**.
#
# - There was a tip left for 71% of total bill, but total bill was 7.25, tip left was 5.15.
# - The highest female tip left was 32.6% on a Saturday.

# %%
# Highest tip_pct for each day
df.groupby(by='day').apply(top, n=1).reset_index(level=1, drop=True).loc[day_order] # returns the highest % using the function we used above already, and returns the days in order.
# Out:
#       total_bill   tip     sex smoker   day    time  size    tip_pct
# day
# Thur        7.51  2.00    Male     No  Thur   Lunch     2  26.631158
# Fri        16.32  4.30  Female    Yes   Fri  Dinner     2  26.348039
# Sat         3.07  1.00  Female    Yes   Sat  Dinner     1  32.573290
# Sun         7.25  5.15    Male    Yes   Sun  Dinner     2  71.034483

# %% [markdown]
# **Highest total bill by time of day.**

# %%
# Code adapted from : https://www.xukun-liu.com/notes/notes/python_ClassNote_13-data-aggregation-group-operations-two.html
# Group data by time, apply top tip % from lunch and dinner, which is index.
df.groupby(by='time').apply(top, column='total_bill').reset_index(1, drop=True).loc[['Lunch','Dinner']]
# Out:
#         total_bill    tip     sex smoker   day    time  size    tip_pct
# time
# Lunch        43.11   5.00  Female    Yes  Thur   Lunch     4  11.598237
# Lunch        41.19   5.00    Male     No  Thur   Lunch     5  12.138869
# Lunch        34.83   5.17  Female     No  Thur   Lunch     4  14.843526
# Lunch        34.30   6.70    Male     No  Thur   Lunch     6  19.533528
# Lunch        32.68   5.00    Male    Yes  Thur   Lunch     2  15.299878
# Lunch        29.80   4.20  Female     No  Thur   Lunch     6  14.093960
# Lunch        28.44   2.56    Male    Yes  Thur   Lunch     2   9.001406
# Lunch        27.20   4.00    Male     No  Thur   Lunch     4  14.705882
# Lunch        27.05   5.00  Female     No  Thur   Lunch     6  18.484288
# Lunch        24.71   5.85    Male     No  Thur   Lunch     2  23.674626
# Dinner       50.81  10.00    Male    Yes   Sat  Dinner     3  19.681165
# Dinner       48.33   9.00    Male     No   Sat  Dinner     4  18.621974
# ...

# %% [markdown]
# ### Smokers
#
# Here we can can see that there was **151 non-smokers, and 93 smokers.**

# %%
df.groupby('smoker').count()
# Out:
#         total_bill  tip  sex  day  time  size
# smoker
# No             151  151  151  151   151   151
# Yes             93   93   93   93    93    93

# %% [markdown]
# Non-smokers total bills were nearly three thousand, as opposed to two thousand for smokers, total tips far higher also.

# %%
# Displays totals for, smoker or not, and their tip size.
df.groupby('smoker').sum()
# Out:
#         total_bill     tip  size
# smoker
# No         2897.43  451.77   403
# Yes        1930.34  279.81   224

# %% [markdown]
# Here we can call a function which displays the tip percent for male/female smokers/non smokers.
# The stat which stands out here is male smokers tipped well below the recommended rate of 15%, they returned an average of 13.6% tip rate verus total bill. Female smokers tipped the highest at 16.3%, but were aso the smallest amount of bill payers at 74. The largest group paying the bill was male, and non-smoker, at 263, next to that group was male smokers at 150, and finally female non-smokers at 140 total bill payers.

# %%
df1= df.groupby(['smoker','sex']).sum() # Function calls Values for smokers and sex.
df1['percent'] = df1['tip']/df1['total_bill']*100 # Per cent cal for tips
df1.dropna() # displays the data
# Out:
#                total_bill     tip  size    percent
# smoker sex
# No     Female      977.68  149.77   140  15.318918
#        Male       1919.75  302.00   263  15.731215
# Yes    Female      593.27   96.74    74  16.306235
#        Male       1337.07  183.07   150  13.691879

# %% [markdown]
# Next we can use a the crosstab, which is function that builds a cross-tabulation table that can show the frequency with which certain groups of data appear. This case will be smokers and sex
#
# Here we can see the figures for smokers or non, and also what sex they were.
# - Neary 62 % per cent did not smoke, leaving 38% as smokers.
# - Male non smokers total was nearly 40% of the group.

# %% [markdown]
# # Ref

# %%
pd.crosstab(index=tips['smoker'], columns=tips['sex'], margins=True).rename(
    columns={"Male": "%_Male", "Female": "%_Female"}).apply(
    lambda row: np.round(100*row/len(tips),1), axis=1)
# Out:
# sex     %_Male  %_Female    All
# smoker
# Yes       24.6      13.5   38.1
# No        39.8      22.1   61.9
# All       64.3      35.7  100.0

# %% [markdown]
# ### Time
#
# Returns the amount of bills for lunch vs dinner.
# - Here we can see dinner times obviously produce more tips, far greater total bill and tip total.

# %%
df.groupby('time').count() # from the df, group the time column, lunch and dinner, and count how many.
# Out:
#         total_bill  tip  sex  smoker  day  size
# time
# Dinner         176  176  176     176  176   176
# Lunch           68   68   68      68   68    68

# %% [markdown]
# Average tip for lunch and dinner.

# %%
df['tip_pct'].groupby(by=df['time']).mean()
# Out:
# time
# Dinner    15.951779
# Lunch     16.412793
# Name: tip_pct, dtype: float64

# %% [markdown]
# **Crosstab** computes a simple cross tabulation of two or more factors.
#
# We can see from this function exactly how many dined for lunch and dinner each day. Thursday Lunch seems to be the only day it's busy for that dining time, Saturday and Sunday are the only busy days for dinner.

# %%
pd.crosstab(index=tips['day'], columns=tips['time'], margins=True)
# Out:
# time  Lunch  Dinner  All
# day
# Thur     61       1   62
# Fri       7      12   19
# Sat       0      87   87
# Sun       0      76   76
# All      68     176  244

# %% [markdown]
# Displays dinner/lunch times data, total bill, tip and size. Dinner was the clear winner here in terms of total bill received.

# %%
df.groupby('time').sum() # group the values in the time column, and return the the sum.
# Out:
#         total_bill     tip  size
# time
# Dinner     3660.30  546.07   463
# Lunch      1167.47  185.51   164

# %% [markdown]
# The functions below return the average for tips each day, for each total bill, and size.

# %%
df1 = df.groupby('day').sum() # Group the Values for each day, and return the sum.
df1['percent'] = df1['tip']/df1['total_bill']*100 # Per cent cal for tips. Dive tips by total bill, and * by 100. 
df1.dropna() # displays the data
# Out:
#       total_bill     tip  size    percent
# day
# Fri       325.88   51.96    40  15.944519
# Sat      1778.40  260.40   219  14.642375
# Sun      1627.16  247.39   216  15.203791
# Thur     1096.33  171.83   152  15.673201

# %% [markdown]
# Below we can see the dinner vs lunch size and total bill, tips and rates. Dinner time clearly generates more tips.

# %%
df1 = df.groupby(['time','size']).sum() # Values for dinner times
df1['percent'] = df1['tip']/df1['total_bill']*100 # Per cent cal for tips
df1.dropna() # displays the data
# Out:
#              total_bill     tip    percent
# time   size
# Dinner 1          10.32    2.00  19.379845
#        2        1791.78  276.84  15.450558
#        3         791.93  115.17  14.542952
#        4         908.95  131.92  14.513450
#        5         109.15   15.14  13.870820
#        6          48.17    5.00  10.379905
# Lunch  1          18.65    3.75  20.107239
#        2         774.11  126.00  16.276757
#        3          92.62   13.77  14.867199
#        4         149.75   21.09  14.083472
#        5          41.19    5.00  12.138869
#        6          91.15   15.90  17.443774

# %% [markdown]
# ### Size

# %% [markdown]
# The greatest size of party was 2 people by far, followed by three people.

# %%
df.groupby(['time', 'size']).count() # Function which counts the size of the parties and dinner times.
# Out:
#              total_bill  tip  sex  smoker  day
# time   size
# Dinner 1              2    2    2       2    2
#        2            104  104  104     104  104
#        3             33   33   33      33   33
#        4             32   32   32      32   32
#        5              4    4    4       4    4
#        6              1    1    1       1    1
# Lunch  1              2    2    2       2    2
#        2             52   52   52      52   52
#        3              5    5    5       5    5
#        4              5    5    5       5    5
#        5              1    1    1       1    1
#        6              3    3    3       3    3

# %% [markdown]
# - From the function below, we can clearly see **smaller tables, two in this case**, generate most tips.
# - We can also see that the highest and lowest tip rate vs total bill was left by the bigger tables. The smaller tables left more consistent recommended tips at the rate of 15%.

# %%
# Day, table size, tip and percentage of the tip vs total bill.
# Adapted from, Python Machine Learning and Stackoverflow.
df1= df.groupby(['day','size']).sum() # Sums up size of parties for each day
df1['percent'] = df1['tip']/df1['total_bill']*100 # Function which cal the percentage of total bill(tip/total bill * 100)
df1.dropna() # Drop null rows(returns object with labels)
# Out:
#            total_bill     tip    percent
# day  size
# Fri  1           8.58    1.92  22.377622
#      2         261.15   42.31  16.201417
#      3          15.98    3.00  18.773467
#      4          40.17    4.73  11.774956
# Sat  1          10.32    2.00  19.379845
#      2         892.37  133.43  14.952318
#      3         459.17   68.36  14.887732
#      4         388.39   53.61  13.803136
#      5          28.15    3.00  10.657194
# Sun  2         684.84  109.86  16.041703
#      3         332.76   46.81  14.067196
#      4         480.39   73.58  15.316722
#      5          81.00   12.14  14.987654
#      6          48.17    5.00  10.379905
# Thur 1          10.07    1.83  18.172790
#      2         727.53  117.24  16.114799
#      3          76.64   10.77  14.052714
#      4         149.75   21.09  14.083472
#      5          41.19    5.00  12.138869
#      6          91.15   15.90  17.443774

# %% [markdown]
# We can clearly see from above how powerful the Pandas library is when it comes to chopping and changing between varibles, producing all kinds of stats. This is only a sample, you can do so much more. <a href="https://pandas.pydata.org/" target="_blank">Here</a> you can find lots more code to become familiar with Pandas library and test data, and on stackoverflow, if you need to debug.

# %% [markdown]
# # SQL
#
#
#
# **Below we can use some examples to show how <a href="https://pandas.pydata.org/pandas-docs/stable/getting_started/comparison/comparison_with_sql.html" target="_blank">SQL</a> operations would be performed using Pandas.**
#
# If you know SQL, or some small amount even, you can do it in Pandas, there are similarities between Pandas and SQL. Regarding job requirements nowadays, most data analysts will be expected to know quite a bit, or the basic SQL functions.
#
# Code adapted from Pandas, comparison with SQL.
#
# SQL has a variety of functions that allow its users to read, manipulate, and change data. Though SQL is commonly used by engineers in software development, it's also popular with data analysts for a few reasons:
#
# - It's semantically easy to understand and learn.
# - Because it can be used to access large amounts of data directly where it's stored, analysts don't have to copy data into other applications.
# - Compared to spreadsheet tools, data analysis done in SQL is easy to audit and replicate. For analysts, this means no more looking for the cell with the typo in the formula.
#
# SQL is great for performing the types of aggregations that you might normally do in an Excel pivot table—sums, counts, minimums and maximums, etc.—but over much larger datasets and on multiple tables at the same time.
#
# SQL is another way we can read and extract data from a URL using Pandas.
#
# You will need to import Pandas as pd, and Numpy as np. We have already done this above. (Mode, 2019)

# %% [markdown]
# ### Select

# %% [markdown]
# In SQL, **SELECT** is done using a comma-separated list of columns you’d like to select (or a * to select all columns)
#
# (Pandas, SQL, 2019)

# %% [markdown]
# SELECT columns, total_bill, tip, smoker, and time FROM df, extract 6 rows.

# %% [markdown]
# **SQL**
#
# SELECT total_bill, tip, smoker, time
#
# FROM tips
#
# LIMIT 7;

# %% [markdown]
# Pandas equivalent to SQL command above.

# %%
df[['total_bill', 'tip', 'smoker', 'time']].head(7)
# Out:
#    total_bill   tip smoker    time
# 0       16.99  1.01     No  Dinner
# 1       10.34  1.66     No  Dinner
# 2       21.01  3.50     No  Dinner
# 3       23.68  3.31     No  Dinner
# 4       24.59  3.61     No  Dinner
# 5       25.29  4.71     No  Dinner
# 6        8.77  2.00     No  Dinner

# %% [markdown]
# Select 10 random rows of data from columns listed.

# %%
# How it is done in Pandas.
df.sample(n=10)[['total_bill', 'tip', 'smoker', 'time']] # from df extract values from total bill, tip, smoker and time, first 6 rows.
# Out:
#      total_bill   tip smoker    time
# 57        26.41  1.50     No  Dinner
# 34        17.78  3.27     No  Dinner
# 210       30.06  2.00    Yes  Dinner
# 41        17.46  2.54     No  Dinner
# 2         21.01  3.50     No  Dinner
# 120       11.69  2.31     No   Lunch
# 161       12.66  2.50     No  Dinner
# 71        17.07  3.00     No  Dinner
# 177       14.48  2.00    Yes  Dinner
# 200       18.71  4.00    Yes   Lunch

# %% [markdown]
# Selecting more random data.

# %%
df.sample(n=3) # ramdonly selects three rows of data.
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 113       23.95  2.55    Male     No  Sun  Dinner     2
# 153       24.55  2.00    Male     No  Sun  Dinner     4
# 67         3.07  1.00  Female    Yes  Sat  Dinner     1

# %% [markdown]
# ### Where

# %% [markdown]
# Filtering in SQL is done via a **WHERE** clause.
#
# DataFrames can be filtered in multiple ways; the most intuitive of which is using boolean indexing.
#
# SELECT FROM tips WHERE sex = 'Male' and LIMIT is 10.

# %% [markdown]
# Here we can extract a certain amount of variables from the sex column.

# %% [markdown]
# **SQL** is done with a WHERE clause by;
#
# SELECT *
#
# FROM df
#
# WHERE time = 'Male'
#
# LIMIT 10;

# %% [markdown]
# Pandas equivalent to it:

# %%
# Pandas is done using BOOLEAN indexing, true or false.
df[df['sex'] == 'Male'].head(10)
# Out:
#     total_bill   tip   sex smoker  day    time  size
# 1        10.34  1.66  Male     No  Sun  Dinner     3
# 2        21.01  3.50  Male     No  Sun  Dinner     3
# 3        23.68  3.31  Male     No  Sun  Dinner     2
# 5        25.29  4.71  Male     No  Sun  Dinner     4
# 6         8.77  2.00  Male     No  Sun  Dinner     2
# 7        26.88  3.12  Male     No  Sun  Dinner     4
# 8        15.04  1.96  Male     No  Sun  Dinner     2
# 9        14.78  3.23  Male     No  Sun  Dinner     2
# 10       10.27  1.71  Male     No  Sun  Dinner     2
# 12       15.42  1.57  Male     No  Sun  Dinner     2

# %% [markdown]
# Here we can see how many males paid the bills, true = 157. We can see female paid 87 bills. This is done with Boolean indexing, true and flase statements.

# %%
is_Male = df['sex'] == 'Male'
is_Male.value_counts()
# Out:
# True     157
# False     87
# Name: sex, dtype: int64

# %% [markdown]
# Returns five rows where sex is male from the sex column.

# %%
# Returns five variables from head of df, where sex is equal to male.
df[is_Male].head(5)
# Out:
#    total_bill   tip   sex smoker  day    time  size
# 1       10.34  1.66  Male     No  Sun  Dinner     3
# 2       21.01  3.50  Male     No  Sun  Dinner     3
# 3       23.68  3.31  Male     No  Sun  Dinner     2
# 5       25.29  4.71  Male     No  Sun  Dinner     4
# 6        8.77  2.00  Male     No  Sun  Dinner     2

# %% [markdown]
#  Multiple conditions can be passed to a DataFrame using (OR) and & (AND).
#
#  **SQL** command:
#
# SELECT *
#
# FROM tips
#
# WHERE time = 'Dinner' AND tip > 4.00;
#
# **SELECT FROM tips WHERE time = 'Dinner' AND tip > 4.00.**
#
#  - Here we can select tips greater than five dollars from the dataframe.
#  - **We can tell from the data returned, male bill-payers generated a lot more high tips.**
#  - 24 out of the 32 tips above four dollars were given by males.

# %% [markdown]
# **'AND' condition using Pandas.**

# %% [markdown]
# Here we can pull data, where the tips are greater than four dollars for the dinner bills.

# %%
# Here we can use the 'AND' condition in Pandas.
df[(df['time'] == 'Dinner') & (df['tip'] > 4.00)] # Select, using boolean, time was dinner, and tip was greater than 4 dollars.
# Out:
#      total_bill    tip     sex smoker  day    time  size
# 5         25.29   4.71    Male     No  Sun  Dinner     4
# 11        35.26   5.00  Female     No  Sun  Dinner     4
# 20        17.92   4.08    Male     No  Sat  Dinner     2
# 23        39.42   7.58    Male     No  Sat  Dinner     4
# 28        21.70   4.30    Male     No  Sat  Dinner     2
# 39        31.27   5.00    Male     No  Sat  Dinner     3
# 44        30.40   5.60    Male     No  Sun  Dinner     4
# 46        22.23   5.00    Male     No  Sun  Dinner     2
# 47        32.40   6.00    Male     No  Sun  Dinner     4
# 52        34.81   5.20  Female     No  Sun  Dinner     4
# 54        25.56   4.34    Male     No  Sun  Dinner     4
# 59        48.27   6.73    Male     No  Sat  Dinner     4
# 73        25.28   5.00  Female    Yes  Sat  Dinner     2
# 93        16.32   4.30  Female    Yes  Fri  Dinner     2
# 95        40.17   4.73    Male    Yes  Fri  Dinner     4
# ...

# %% [markdown]
# Tips by parties of at least 5 diners OR bill total was more than $50.
#
# **SQL** command:
#
# SELECT *
#
# FROM tips
#
# WHERE size >= 5 OR total_bill > 45;
#
# **'OR' condition in Pandas**

# %% [markdown]
# The function below returns two statements, display data where size was greater than or equal to five, or total bill was greater than 45 dollars.

# %%
# No we can use the 'OR' condition.
# SELECT FROM tips WHERE size >= 5 OR total_bill > 50.
df[(df['size'] >= 5) | (df['total_bill'] > 45)]
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 125       29.80   4.20  Female     No  Thur   Lunch     6
# 141       34.30   6.70    Male     No  Thur   Lunch     6
# 142       41.19   5.00    Male     No  Thur   Lunch     5
# 143       27.05   5.00  Female     No  Thur   Lunch     6
# 155       29.85   5.14  Female     No   Sun  Dinner     5
# 156       48.17   5.00    Male     No   Sun  Dinner     6
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3
# 185       20.69   5.00    Male     No   Sun  Dinner     5
# 187       30.46   2.00    Male    Yes   Sun  Dinner     5
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 216       28.15   3.00    Male    Yes   Sat  Dinner     5

# %% [markdown]
# ### Groupby
# "In pandas, SQL’s GROUP BY operations are performed using the similarly named groupby() method. groupby() typically refers to a process where we’d like to split a dataset into groups, apply some function (typically aggregation) , and then combine the groups together.
#
# A common SQL operation would be getting the count of records in each group throughout a dataset. For instance, a query getting us the number of tips left by sex." (Comparison with SQL, 2019)
#
# **SQL command**:
#
# SELECT sex, count(*)
#
# FROM tips
#
# GROUP BY sex;
#
# **Ouptut**:
#
# /*
# Female     87
#
# Male      157
# */

# %% [markdown]
# The Pandas equivalent would be as follows:

# %%
df.groupby('sex').size() # from df return sex bill payers.
# Out:
# sex
# Female     87
# Male      157
# dtype: int64

# %% [markdown]
# **Pandas**
#
# Sat and Sunday were the busiest days, which also generated the higher tips.

# %%
df.groupby('day').agg({'tip': np.mean, 'day': np.size}) # from df return average tip, and the amount of bills for each day.
# Out:
#            tip  day
# day
# Fri   2.734737   19
# Sat   2.993103   87
# Sun   3.255132   76
# Thur  2.771452   62

# %% [markdown]
# **SQL** command for groupby.
#
# SELECT smoker, day, COUNT(*), AVG(tip)
#
# FROM tips
#
# GROUP BY smoker, day;

# %% [markdown]
# Below returns stats which display smoker or non, day, tip size and average tip size.

# %%
# Pandas equivalent to the groupby SQL command above.
# If we want to group more than one columns the following command is done.
# Returns, smokers vs non, tip size and their average for each day.
df.groupby(['smoker', 'day']).agg({'tip': [np.size, np.mean]})
# Out:
#               tip
#              size      mean
# smoker day
# No     Fri    4.0  2.812500
#        Sat   45.0  3.102889
#        Sun   57.0  3.167895
#        Thur  45.0  2.673778
# Yes    Fri   15.0  2.714000
#        Sat   42.0  2.875476
#        Sun   19.0  3.516842
#        Thur  17.0  3.030000

# %% [markdown]
# Some of the above commands are very useful if you are working with large data-sets. SQL is not a hard programing language to learn, and most data analysts are required to know some amount of it. Data can be manipulated through SQL using basic queries.

# %% [markdown]
# # Next we will look at Plotting with Seaborn.
#
# ### Visualization using Seaborn.
#
# ![image](ImagesFun/Seaborn1.png) Source (Journal Dev, 2019)
#
# This can be achieved by multivariate plots which can reveal the relationship among several variables simultaneously which generally include the form, strength and dependence of each relationship. There are numerous plots available to display your findings such as, 2D, 3D, colour, scatter plots etc. The closer the dots come together on scatter plots, the stronger the relationship.
#
#
# Easy to spot trends or relationships between the values, variables in the plots as we can see the many different examples <a href="https://seaborn.pydata.org/examples/index.html" target="_blank">here</a>
#
#
# The scatter plot is a cornerstone of statistical visualization, using a cloud of points.
#
# There are several ways to draw a scatter plot in seaborn. The most basic, which should be used when both variables are numeric, is the scatterplot() function.
#
#
#
# **You will need to import Seaborn and Matplotlib of you haven't done so already.**

# %% [markdown]
# **Saturday and Sunday are the most busy over the four days.**

# %%
# Displays tables per day.
# Days on the x axis, the amount of bills each day on the y axis. 
sns.set(style="darkgrid") # default colour for the grid in Seaborn.
sns.countplot(x='day' ,data=df)

# %% [markdown]
# - Very clearly displays party size of two being the most frequent.

# %%
# This function displays the days on the x axis,
# Count on the y axis'
# The hue will display the size of the parties on the top right side of the plot.
sns.countplot(x='day',hue='size' ,data=df)

# %% [markdown]
# #### Relating variables with scatterplots.
# #### Tips versus Bill.
# - We can see from the scatterplot below that the total bill was mostly in the range of between 10 and 25 dollars.
# - Very few bills were above 40 dollars, and most of the tips were between 1.50 and 4 dollars.
# - It also looks like the min total bill is around one dollar, and max around 50 dollars.

# %%
# There are several ways to draw a scatter plot in seaborn. 
# The most basic, which should be used when both variables are numeric, is the scatterplot()
sns.set(style="darkgrid") # default colour for the grid in Seaborn.
tips = sns.load_dataset("tips") # Loads the data 
# Relplot is a figure-level interface for drawing relational plots onto a FacetGrid.
sns.relplot(x="total_bill", y="tip", data=tips); # Displays the total bill on x axis, and tip on y axis.

# %% [markdown]
# The plot above is all in the one colour, **to display the data more effectively in multi-dimensional** with smokers or non, do the following;

# %%
# Hue - Hue semantic, adds another dimension to the plot with colours, for smokers and non-smokers.
sns.relplot(x="total_bill", y="tip", hue="smoker", data=tips);

# %% [markdown]
# - From the plot above which displays smokers vs non-smokers we can clearly see that the biggest tip was given by a smoker, who also had the largest total bill.
#
# - There also seem to be more of a relationship between the non-smokers. Tha variability of the smokers is a lot more scattered.

# %% [markdown]
# One of the plots that seaborn can create is a countplot. A countplot is like a histogram or a bar graph, for some categorical area.

# %%
# Function that smokers or non, for each day with a hue colouring the data for smoker or non differently.
sns.countplot(x='day',hue='smoker' ,data=df)

# %% [markdown]
# - We can see from the countplot we did, Sunday, Saturday and Thursday's bill payers were predominantly smokers.

# %% [markdown]
# #### Below we can see that male bill-payers paid the largest bills mostly, and seems  more men than women paid the bill on Saturday and Sunday.
#
#
# **Catplot** function provides a new framework giving access to several types of plots that show relationship between numerical variable and one or more categorical variables, like boxplot, stripplot and so on. Catplot can handle 8 different plots currently available in Seaborn. catplot function can do all these types of plots and one can specify the type of plot one needs with the kind parameter. (Python and R Tips, 2019)

# %%
tips = sns.load_dataset("tips") # Load dataset from seaborn,
# Function below kind=swarm is a categorical scatterplot with non-overlapping points, demonstrates data more efective.
sns.catplot(x="day", y="total_bill", hue="sex", kind="swarm", data=tips); # Label the axis, days, total bill,
#  and hue: male/female, colours the data points differently.

# %% [markdown]
# We can also recognise from the **catplot** below that it was much busier on Saturday and Sunday, with greater total bills also.

# %%
# The function Catplot provides access to several axes-level functions that show the relationship,
# between a numerical and one or more categorical variables,
# using one of several visual representations. (https://seaborn.pydata.org/generated/seaborn.catplot.html)
sns.catplot(x="day", y="total_bill", kind="swarm", data=tips);

# %% [markdown]
# ## Multi Plots
#
# **Here we can read multi-dimensional arrays on a number of plots at once.**
#
# <a href="https://www.tutorialspoint.com/seaborn/seaborn_facet_grid.htm">Facetgrid</a> which we will be using below, is an object which takes a dataframe as input and the names of the variables that will form the row, column, or hue dimensions of the grid. The variables should be categorical and the data at each level of the variable will be used for a facet along that axis.

# %%
sns.set(style="ticks")# built in Seaborn themes which style the plots. (Codecademy, 2019)

# %%
# Load dataset, looks for online csv files,
tips = sns.load_dataset("tips") # writing the function: tips = the dataset we have already imported through Seaborn.

# %% [markdown]
# ### Male/female and Smoker/Non-Smoker Relationships.
# - Below we can see that the male tips were larger, and more scattered.
# - You can predict womens tips, as there is much more of a relationship between them using the data.
# - Male non-smokers seem to give larger tips, and unpredictable tips.

# %%
# Multi-plot grid for plotting conditional relationships. 
# function hue=smoker belows, tells Seaborn you want the data points for smoker and non smoker coloured differently.
g = sns.FacetGrid(tips, col="sex", hue="smoker") # takes a dataframe as input and the names of the variables,
# that will form the dimensions of the grid. Sex above the plot, smoker to the right in a hue.
g.map(plt.scatter, "total_bill", "tip", alpha=.7) # Maps the values acroos the plot
g.add_legend(); # Labels the data, and draws a legend, placing it outside axes and resizing the figure.

# %% [markdown]
# Again using multi-plots, we can see in the two plots below, that smokers bills had a more scattered relationship, males tips were larger than females, smokers were less predictable over the non-smokers, which we can see more of a relationship.

# %%
# Below is code for colour, background, smoker or non, values on the x and y axis, width and height, tip and total bill.
g = sns.FacetGrid(tips, col="smoker", margin_titles=True, height=4) # 
g.map(plt.scatter, "total_bill", "tip", color="#338844", edgecolor="white", s=50, lw=1) # setting values, colours, width etc.
for ax in g.axes.flat:
    ax.plot((0, 50), (0, .2 * 50), c=".2", ls="--")
g.set(xlim=(0, 60), ylim=(0, 14));

# %% [markdown]
# Below we can determine there was much more of a relationship between the non-smokers tips, especially male. Smokers seem a lot more difficult to predict.

# %%
with sns.axes_style("white"): # Set the colour of the plot
    g = sns.FacetGrid(tips, row="sex", col="smoker", margin_titles=True, height=2.5) # Multi-plot grid for plotting conditional relationships.
g.map(plt.scatter, "total_bill", "tip", color="#334488", edgecolor="white", lw=.5); # maps the values on the plot.
g.set_axis_labels("Total bill (US Dollars)", "Tip"); #  Naming the variables on the axis.
g.set(xticks=[10, 30, 50], yticks=[2, 6, 10]); # xticks are values used to show specific points on the coordinate x axis.
g.fig.subplots_adjust(wspace=.02, hspace=.02); # width and height

# %% [markdown]
# Here the difference between lunch and dinner, in terms of tips dinner is vastly more.

# %%
g = sns.FacetGrid(tips, col="time") # Multi-plot grid for plotting conditional relationships.

g.map(plt.hist, "tip"); # Outputs the tips variables on a histogram.

# %% [markdown]
# #### Default Jitter
# - Below we can see the size of the party, was mostly two at lunch. At dinner it varied much more from two to four people.
# - Also using the default jitter so we can see the difference with that and one we can specify the amount of jitter we want.

# %%
g = sns.FacetGrid(tips, row="smoker", col="time", margin_titles=True) # Ouputs somkers and time outside the plots.
# The function below plots the above variables, with size and total bill.
# By default, a linear regression fit is drawn, you can remove it with fit_reg=False. 
# Jitter displays values which overlap, more effectively. Can specify the amount of jitter or just use True for a good default.
g.map(sns.regplot, "size", "total_bill", color=".3", fit_reg=False, x_jitter=True);

# %% [markdown]
# #### Ajusting the jitter.

# %%
g = sns.FacetGrid(tips, row="smoker", col="time", margin_titles=True) # Ouputs somkers and time outside the plots.
# The function below plots the above variables, with size and total bill.
# By default, a linear regression fit is drawn, you can remove it with fit_reg=False. 
# Jitter displays values which overlap, more effectively. Can specify the amount of jitter or just use True for a good default.
g.map(sns.regplot, "size", "total_bill", color="r", fit_reg=False, x_jitter=.1);

# %% [markdown]
# - Again in multi-plots, we can spot multiple relationships between days, sex and total bill below.
# - Males paid for more bills on Thurs, Sat and Sunday, while on Friday they paid much more.

# %%
g = sns.FacetGrid(tips, col="day", height=4, aspect=.5) # Displays days above the plots, height and aspect(width of plots)
g.map(sns.barplot, "sex", "total_bill"); # Function which displays the sex on the x axis, and total bill on y axis.
# Out:
# C:\Users\owner\Anaconda\lib\site-packages\seaborn\axisgrid.py:715: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# ## Plotting pairwise data relationships
# - Plotting all pairs of values against each other.
# - PairGrid allows us to draw a grid of subplots using the same plot type to visualize data.
#
# - Unlike FacetGrid, it uses different pair of variable for each subplot. It forms a matrix of sub-plots. It is also sometimes called as “scatterplot matrix”.
#
# The usage of pairgrid is similar to facetgrid. First initialise the grid and then pass the plotting function.
# - https://www.tutorialspoint.com/seaborn/seaborn_pair_grid.htm
#
# #### Here we can spot variables that relate to each other.
# - It is clearly visible that there are relationships between large tips and big parties.
# - Most of the tips are coming from bills between 15 and 30 dollars.
# - And parties between 2 and 4 people clearly was the average size of the party.

# %%
# PairGrid allows us to draw a grid of subplots using the same plot type to visualize data differently.
g = sns.PairGrid(tips)
g.map(plt.scatter);

# %% [markdown]
# - Below we can spot each catergorical variable by colour.
# - We can determine the tip size by size of party.
#
# From the function we call below, we can see parties of two people made up most of the bills and left the most tips, followed by parties of three and four people.

# %%
# Function below lets us visualize the size of the parties,in different colours, one to six in this case.
g = sns.PairGrid(tips, hue="size") # Displays the values (size party) in diff colours.
g.map_diag(plt.hist)# Maps the data in multiple histograms.
g.map_offdiag(plt.scatter) # Scatterplot
g.add_legend(); # Labels the data (size of parties)

# %% [markdown]
# - We can also use another function in the upper and lower triangle to see different aspects of the relationship.

# %%
# 9 plots, 3 cols, and 3 rows. 
# Right of plots is dinner time. 
# Histograms going from top left to bottom right.
# The other 6 are scatterplots.
# Can establish tip size between dinner times, if any.
sns.pairplot(df, hue='time')

# %% [markdown]
# **Here we can look at various different styles of plots to help us distinguish between multiple variables at once.**
#
# We can see most of tips are between 2 and 6 dollars, size is 2, most of the bills were between 10 and 30 dollars.

# %%
g = sns.PairGrid(tips) # Plotting pairwise relationships in dataset.
g.map_upper(plt.scatter) # Maps the values on the plot.
g.map_lower(sns.kdeplot) # Fit and plot a univariate or bivariate kernel density estimate. (kdeplot)
g.map_diag(sns.kdeplot, lw=3, legend=False); # Set lw, and no legend.

# %% [markdown]
# #### Faceted Histogram.
# Below we can see male bill payers were much higher at dinner time. We will use facetgrid to display this in a histogram. (Multi-plot grid for plotting conditional relationships.

# %%
# Load df 
tips = sns.load_dataset('tips')
tips['tip_pct'] = 100 * tips['tip'] / tips['total_bill'] # Function cal the tips per cent.

grid = sns.FacetGrid(tips, row="sex", col="time", margin_titles=True) # Setting variables from col and rows in dataframe.
grid.map(plt.hist, "tip_pct", bins=np.linspace(0, 40, 15)); # Map the values from the functions we called above, and display output.

# %% [markdown]
# ### Here we can see some Catplots.
#
# <a href="https://cmdlinetips.com/2019/03/catplot-in-seaborn-python/" target="_blank">Catplots</a> can handle 8 different plots currently available in Seaborn.
# - Often used in explanatory data analysis. This type of graph is used to show the shape of the distribution, its central value, and its variability. In a box and whisker plot: the ends of the box are the upper and lower quartiles, so the box spans the interquartile range. (https://www150.statcan.gc.ca/n1/edu/power-pouvoir/ch12/5214889-eng.htm)

# %% [markdown]
# Underneath we can see in the boxplot that Sat and Sunday were the busiest days.

# %%
sns.catplot(x="day", y="total_bill", kind="box", data=tips); # Set day, total bill and style of plot.

# %% [markdown]
# And again below, it displays non-smokers had the had greater variance in total bills on Saturday and Sunday.

# %%
# Displays catplot, bills between smokers and non.
sns.catplot(x="day", y="total_bill", hue="smoker", kind="box", data=tips);

# %% [markdown]
# ## Linear Relationships
# - Many datasets contain multiple quantitative variables, and the goal of an analysis, is often to relate those variables to each other.
# - It can be very helpful, though, to use statistical models to estimate a simple relationship between two noisy sets of observations. (https://seaborn.pydata.org/tutorial/regression.html)
#
# - This can be done through the regression lines.
# - Linear regression is a very simple supervised machine learning algorithm – we have data (X , Y) with linear relationship. we want to predict unknown Y values for given X. X can be one or more parameters. (Python Machine Learning)
#
# There are two main functions in Seaborn to visualize a linear relationship determined through regression. These functions are **regplot()** and **lmplot().**
# - *Regplot*: accepts the x and y variables in a variety of formats including simple numpy arrays, pandas Series objects, or as references to variables in a pandas DataFrame.
# - *Implot*: has data as a required parameter and the x and y variables must be specified as strings. This data format is called “long-form” data. (https://www.tutorialspoint.com/seaborn/seaborn_linear_relationships.htm)

# %%
sns.set(color_codes=True) # Setsfont size and the background style on plot.
tips = sns.load_dataset("tips") # Load data from df

# %% [markdown]
# - **Implot**: Total bill vs Tip.
# - Notice the difference in size between the two plots.
# - Majority of tip size is 1.5 to 4 dollars, and total bill majority, 10 to 25.

# %%
# Implot, 2D scatterplot with an optional overlaid regression line. This is useful for comparing numeric variables. 
sns.lmplot(x ="total_bill", y = "tip", line_kws={"color": "red"}, data = tips) # Sets values and line colour.
plt.show() # Displays plot.

# %% [markdown]
# - **Replot**: Total bill vs Tip.
# - Here we can see the vast amount of total bill and tips are, 10 to 25 dollars total bill and tip size 1.50 to 4 dollars.

# %%
# Replot, plot data and a linear regression model fit.
sns.regplot(x ="total_bill", y ="tip", line_kws={"color": "green"}, data = tips)# plots variables and sets line colour green.

# %% [markdown]
# - Implot.: Tips vs Size of party.
# - Some of the values can be hard to distinguish in this plot.

# %% [markdown]
# **Implot** without **jitter**. (Jitter spreads out variables a little, easier to visualize.)

# %%
sns.lmplot(x="size", y="tip", line_kws={"color": "orange"}, data=tips);

# %% [markdown]
# - **Implot** with **Jitter**, option to add some random noise (“jitter”) to the discrete values to make the distribution of those values more clear.

# %%
# Jitter helps display clustered variables.
sns.lmplot(x="size", y="tip", line_kws={"color": "black"}, data=tips, x_jitter=.05);# Can change jitter size, sets the values for plot.

# %% [markdown]
# - Below in a pairplot, we can clearly see again the relationship amoung non-smokers, a lot easier to predict over smokers.

# %%
# Using the pairplot() function with kind="reg" combines regplot() and PairGrid,
# to show the linear relationship between variables in a dataset. 
sns.pairplot(tips, x_vars=["total_bill", "size"], y_vars=["tip"],# set variables for axis, displays two plots. 
             hue="smoker", height=5, aspect=.8, kind="reg"); # labels value, and outputs a line for each value, smoker or non.

# %% [markdown]
# ## Quick summary of all the data extracted and displayed from above.

# %% [markdown]
# ***Predicting a tip on a given day.***

# %%
df1 = df.groupby('day').sum() # Values for each day.
df1['percent'] = df1['tip']/df1['total_bill']*100 # Per cent cal for tips
df1.dropna() # displays the data
# Out:
#       total_bill     tip  size    percent
# day
# Fri       325.88   51.96    40  15.944519
# Sat      1778.40  260.40   219  14.642375
# Sun      1627.16  247.39   216  15.203791
# Thur     1096.33  171.83   152  15.673201

# %%
# from df return average tip, and the amount of bills for each day.
df.groupby('day').agg({'tip': np.mean, 'total_bill': np.size})
# Out:
#            tip  total_bill
# day
# Fri   2.734737        19.0
# Sat   2.993103        87.0
# Sun   3.255132        76.0
# Thur  2.771452        62.0

# %% [markdown]
# ***Total Bill and Tip***

# %% [markdown]
# Here we can see the total bill vs the tip size. It is 15%, which is about right for the recommended tipping rate in USA.

# %%
df1= df.groupby('sex').sum() # Function calls Values for smokers and sex.
df1['percent'] = df1['tip']/df1['total_bill']*100 # Per cent cal for tips
df1.dropna() # displays the data
# Out:
#         total_bill     tip  size    percent
# sex
# Female     1570.95  246.51   214  15.691779
# Male       3256.82  485.07   413  14.893976

# %% [markdown]
# Plot below illustrates all the data points for bill vs tip.

# %%
# Implot, 2D scatterplot with an optional overlaid regression line. This is useful for comparing numeric variables. 
sns.lmplot(x ="total_bill", y = "tip", line_kws={"color": "red"}, data = tips) # Sets values and line colour.
plt.show() # Displays plot.

# %% [markdown]
# **Male Vs Female bill payee.**

# %% [markdown]
# Using Boolean, we can see how many bills were paid by male/female.

# %%
is_Male = df['sex'] == 'Male'
is_Male.value_counts()
# Out:
# True     157
# False     87
# Name: sex, dtype: int64

# %% [markdown]
# Male/female figures for total bill, tips and size of parties.

# %%
df.groupby('sex').sum()
# Out:
#         total_bill     tip  size
# sex
# Female     1570.95  246.51   214
# Male       3256.82  485.07   413

# %% [markdown]
# Here we can see the tipping per cent ranges for the male and females.

# %%
df1 = df.groupby('sex').sum() # Values for dinner times
df1['percent'] = df1['tip']/df1['total_bill']*100 # Per cent cal for tips
df1.dropna() # displays the data
# Out:
#         total_bill     tip  size    percent
# sex
# Female     1570.95  246.51   214  15.691779
# Male       3256.82  485.07   413  14.893976

# %% [markdown]
# **Smoker vs Non-Smoker**

# %%
df.groupby('smoker').count() # Returns the values for smokers and non.
# Out:
#         total_bill  tip  sex  day  time  size
# smoker
# No             151  151  151  151   151   151
# Yes             93   93   93   93    93    93

# %%
# Displays totals for, smoker or not, and their tip size.
df.groupby('smoker').sum()
# Out:
#         total_bill     tip  size
# smoker
# No         2897.43  451.77   403
# Yes        1930.34  279.81   224

# %% [markdown]
# The stat which stands out here is male smokers tipped well below the recommended rate of 15%, they returned an average of 13.6% tip rate verus total bil.

# %%
df1= df.groupby(['smoker','sex']).sum() # Function calls Values for smokers and sex.
df1['percent'] = df1['tip']/df1['total_bill']*100 # Per cent cal for tips
df1.dropna() # displays the data
# Out:
#                total_bill     tip  size    percent
# smoker sex
# No     Female      977.68  149.77   140  15.318918
#        Male       1919.75  302.00   263  15.731215
# Yes    Female      593.27   96.74    74  16.306235
#        Male       1337.07  183.07   150  13.691879

# %% [markdown]
# **Lunch versus Dinner**

# %% [markdown]
# Total bills, tips and sizes for lunch and dinner.

# %%
df.groupby('time').sum()# Displays dinner/lunch times data.
# Out:
#         total_bill     tip  size
# time
# Dinner     3660.30  546.07   463
# Lunch      1167.47  185.51   164

# %% [markdown]
# Lunch had 68 total bills and dinner had 176.

# %%
df.groupby('time').count() # Returns total bills for lunch or dinner.
# Out:
#         total_bill  tip  sex  smoker  day  size
# time
# Dinner         176  176  176     176  176   176
# Lunch           68   68   68      68   68    68

# %% [markdown]
# Lunch was far quieter, but had an over-all higher tip rate.

# %%
df1 = df.groupby('time').sum() # Values for each day.
df1['percent'] = df1['tip']/df1['total_bill']*100 # Per cent cal for tips
df1.dropna() # displays the data
# Out:
#         total_bill     tip  size    percent
# time
# Dinner     3660.30  546.07   463  14.918723
# Lunch      1167.47  185.51   164  15.889916

# %% [markdown]
# Two clearly was the greatest size of the parties which arrived for lunch and dinner.

# %%
df.groupby(['time', 'size']).count() # Function which counts the size of the parties and dinner times.
# Out:
#              total_bill  tip  sex  smoker  day
# time   size
# Dinner 1              2    2    2       2    2
#        2            104  104  104     104  104
#        3             33   33   33      33   33
#        4             32   32   32      32   32
#        5              4    4    4       4    4
#        6              1    1    1       1    1
# Lunch  1              2    2    2       2    2
#        2             52   52   52      52   52
#        3              5    5    5       5    5
#        4              5    5    5       5    5
#        5              1    1    1       1    1
#        6              3    3    3       3    3

# %% [markdown]
# **Size of parties.**
#
# Dinner Size majority of tables seem to be party sizes of two.

# %%
df.groupby('size').count()
# Out:
#       total_bill  tip  sex  smoker  day  time
# size
# 1              4    4    4       4    4     4
# 2            156  156  156     156  156   156
# 3             38   38   38      38   38    38
# 4             37   37   37      37   37    37
# 5              5    5    5       5    5     5
# 6              4    4    4       4    4     4

# %%
# Jitter helps display clustered variables.
sns.lmplot(x="size", y="tip", line_kws={"color": "black"}, data=tips, x_jitter=.05);# Can change jitter size, sets the values for plot.

# %% [markdown]
# Now we can see the party size for each day. Seems to be very little or none, for size of one some days. Friday seems to be extremely quiet. This could be down to location, NFL, NHL and NBA are on Thursday, Saturday and Sundays in America. This could be one of the reasons for total bills, and size of parties.

# %%
df1= df.groupby(['size', 'day']).count() # Sums up size of parties for each day.
df1.dropna() # returns values
# Out:
#            total_bill  tip  sex  smoker  time
# size day
# 1    Fri            1    1    1       1     1
#      Sat            2    2    2       2     2
#      Thur           1    1    1       1     1
# 2    Fri           16   16   16      16    16
#      Sat           53   53   53      53    53
#      Sun           39   39   39      39    39
#      Thur          48   48   48      48    48
# 3    Fri            1    1    1       1     1
#      Sat           18   18   18      18    18
#      Sun           15   15   15      15    15
#      Thur           4    4    4       4     4
# 4    Fri            1    1    1       1     1
#      Sat           13   13   13      13    13
#      Sun           18   18   18      18    18
#      Thur           5    5    5       5     5
# 5    Sat            1    1    1       1     1
#      Sun            3    3    3       3     3
#      Thur           1    1    1       1     1
# 6    Sun            1    1    1       1     1
# ...

# %% [markdown]
# And finally we can see the tip per cent given by each party size.

# %%
df1= df.groupby('size').sum() # Sums up size of parties for each day
df1['percent'] = df1['tip']/df1['total_bill']*100 # Function which cal the percentage of total bill(tip/total bill * 100)
df1.dropna()
# Out:
#       total_bill     tip    percent
# size
# 1          28.97    5.75  19.848119
# 2        2565.89  402.84  15.699816
# 3         884.55  128.94  14.576904
# 4        1058.70  153.01  14.452631
# 5         150.34   20.14  13.396302
# 6         139.32   20.90  15.001436

# %% [markdown]
# # Findings.
#
# What did we find interesting from all the variabes we analyzed, can the data be used to improve the company's present strategy, resources, and enhance competitive advantage? Tip rates can be a very effective tool, in terms of identifying strengths/weaknesses within a company.
#
# **Can we predict the busiest day, and what the tips will be on that day?**
# ![image](ImagesFun/DayTips.png) ![image](ImagesFun/DayTips1.png)
# Yes we can, from our findings above, we could determine the average tip size for everyday, based on total bills. Saturday was the busiest day with 87 bills, Sunday was next with 76, Thursday with 62 and Friday was the least busy with 19 bills. Saturday and Sunday were the busiest days, which returned most tips, 219 dollars and 216 dollars in total tips. Thurs generated 152 dollars, while Friday the least busy day generated 40 dollars. Highest tips generated was on Saturday, 260 dollars, at a rate of 14.6% of the total bill. From the data we pulled to get these figures, the recommeded tip-rate is just about being met, which indicates overall service is not excetional, which would stand out in weaknesses in a S.W.O.T. analysis.
#
#
#
# **Relationship between total bill and tip size.**
#
# The relationship bewteen the total bill and tip size seems to be around 15%. This is available to see in some of the plots which was used through Seaborn. Very few diners spent above 40 dollars, most were in the 10 dollars to 25 range, and if they did, tip size was still around 15%. Mangement can use this data very effectively, in terms of customer service and experience. The average bill which was 20 dollars, and average tip around three dollars, can also indicate that geographics maybe a big factor, wages determine tip size, along with quality of service.  ![image](ImagesFun/TotalBill.png)
#
#
#
# **Does the party size, times, esp at weekends, determine tip size?**
#
# We can also see that there were no parties for the size of one on Sunday's, and also Sunday's and Thursday's were the only days with parties of six. Maybe on Thursdays, a lot of work colleagues got together and went out, as do quite a few nowadays. On Sunday I think the parties were from two up, is beacuse it is a day when families get together and go for lunch, likewise couples.
#
# Yes the party size definitely plays a major factor from the stats we pulled above. We can see that party size of two and six people generates the highest tips and best overall rate, 15.7%.  ![image](ImagesFun/Size.png) ![image](ImagesFun/Bill1.png)
#
#
# **Are the tips too small or big, should the tips be raised or reduced?**
#
# The standard recommended rate to tip in U.S.A. is 15% of the total bill. If you received excellent service you normally tip bewteen 15 and 25% of the total bill. We can see that most of the tips were around 15%. We can see that the average tip was a little over 15%. I think 15% is about right, and if you feel like you got exceptional service you may choose to tip more if you like. ![image](ImagesFun/Tip1.png)
#
# **Tips size can determine your overall service at a restaurant, does it need to be improved, and how?**
#
# One way managment can rate their employee's performance, can be through tips. Like we discussed above, if the service is exceptional you are deemed to tip between 20% and 25%. Clearly we saw that the average is around 15%, so expectations over all are deemed to be met. This might not be all down to employees though, food quality and environment maybe needs to be looked at also. So, food service training, improving the menu and contents of restaurant, and geographics, maybe all areas you can look at to try and improve. If this is the case, there is a good chance you will see the overall average tip rate increase.
#
# **Does one sex leave larger tips than the other sex, if so, why this is the case?**
#
# Generally men leave larger tips than women, as we saw above the highest tip by a male was ten dollars and highest female tip was six dollars and fifty cent. We have found from above, that men's tips seem to have a far less relationship, women on the other hand have far more of a relaionship, they seem to be more steady and reliable tippers. Why is this the case? There are a number of factors, wages are one of the biggest, geographics, mood, service obviously being the most important. As for why men tip more, could be down to men trying to impress someone maybe. We did see in some of the scatterplots above, some of the bigger tips, which were spread out, were indeed males.
#
#
# **Excellent Python Libraries.**
#
# All the above data that we extracted from the csv file, the waiter tips data-set, using libraries such as Pandas and Seaborn, clearly demonstrates, we can use those libraires and the data to predict/forecast what the waiters tips will likely be on a given day and time. They are effective tools for mangement also, on ways to improve and enhance the business needs. Using the data and libraries to output statistics, and display them on plots, demonstrates they are very effective libraries to use in Data Analytics, when wanting to display findings to management who are not familiar in this area. (Please find a more details and breakdown of stats pulled from the data-set in the Read.ME file, under findings.)

# %% [markdown]
# ## Bibliography
# Pandas, 2019, viewed on 2019/10/16, available at: https://pandas.pydata.org/pandas-docs/stable/
#
# Seaborn, 2019, viewed on 2019/11/04, available at: https://seaborn.pydata.org/tutorial.html
#
# Inquiries Journal, 2019, viewed on 2019/10/16, available at: http://www.inquiriesjournal.com/articles/922/how-much-should-i-tip-restaurant-tipping-behavior-as-a-result-of-prior-foodservice-experience
#
# From The Grape Vine, 2016, viewed on 2019/11/02, available at: https://www.fromthegrapevine.com/lifestyle/who-gives-more-tips-men-or-women#:~:targetText=A%202007%20Gallup%20study%20found,So%20women%20tip%20more.
#
# Di Cook, Case Study, viewed on the 2019/11/02, available online at: https://dicook.public.iastate.edu/stat503/05/cs-tips2.pdf
#
# Seaborn, 2019, viewed on 2019/11/05, available at: https://seaborn.pydata.org/generated/seaborn.stripplot.html
#
# Python Machine Learning, 2017, viewed on, 2019/11/05, available at: https://devarea.com/python-machine-learning-example-linear-regression/#.XcGIlTP7TIU
#
# Python and R Tips, 2019, viewed on 2019/11/06, available at: https://cmdlinetips.com/2019/03/catplot-in-seaborn-python/
#
# Codecademy, 2019, viewed on 2019/11/06, available at: https://www.codecademy.com/articles/seaborn-design-i
#
# Seaborn, 2019, viewed on 2019/11/05, available at: https://seaborn.pydata.org/generated/seaborn.stripplot.html
#
# Seaborn, 2019, viewed on 2019/11/06, available at: https://seaborn.pydata.org/tutorial/axis_grids.html
#
# Pandas, 2019, Comparison with SQL, viewed on 2019/11/20, available at: https://pandas.pydata.org/pandas-docs/stable/getting_started/comparison/comparison_with_sql.html
#
# Mode, The SQL Tutorial for Data analysis, viewed on 2019/11/20, available at: https://mode.com/sql-tutorial/introduction-to-sql#:~:targetText=Though%20SQL%20is%20commonly%20used,copy%20data%20into%20other%20applications.
#
# Journal Dev, 2019, Seaborn, viewed on 2019/11/28, available at: https://www.journaldev.com/18583/python-seaborn-tutorial
